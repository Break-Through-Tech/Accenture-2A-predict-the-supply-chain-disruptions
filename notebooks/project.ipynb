# %% [markdown]
# notebook for accenture project

# %%
import pandas as pd
import os

# %%
filename = os.path.join("..", "data", "weekly_route_operations.csv")
df = pd.read_csv(filename, header=0)

# %%
example_data = {"name": ["Alice", "Yala", "Tim"], "age": [67, 55, 91]}
df = pd.DataFrame(example_data)
print(df)
# Out:
#     name  age
# 0  Alice   67
# 1   Yala   55
# 2    Tim   91
